# %% [markdown]
# # **API's**
#
# Según la investigación realizada, dimos con la API publica *Mapquest* la cual ayuda a los desarrolladores con soluciones geoespaciales.
#
# https://developer.mapquest.com/documentation/directions-api/route/get/

# %%
import requests
from urllib.request import urlopen
import json
import pandas as pd

# %% [markdown]
# En relación con el dataset de nuestro proyecto, utilizaremos la API Mapquest para encontrar la ubicación de distintas ciudades y la cercanía de las mismas.

# %%
import requests
from requests.structures import CaseInsensitiveDict

api_key = "q5fjDfbXlkqzl1NpDu4BEjWc4gWe5dvm"
url = "http://www.mapquestapi.com/directions/v2/route?key={}".format(api_key)

headers = CaseInsensitiveDict()
headers["Content-Type"] = "application/json"

data = """
{
  "locations": [
        "Mumbai",
        "Delhi"
    ]
  }
}
"""


resp = requests.post(url, headers=headers, data=data)
resp.text
# Out:
# '{"route":{"hasTollRoad":true,"hasBridge":false,"boundingBox":{"lr":{"lng":77.227051,"lat":18.952568},"ul":{"lng":72.831856,"lat":28.657734}},"distance":866.862,"hasTimedRestriction":false,"hasTunnel":false,"hasHighway":true,"computedWaypoints":[],"routeError":{"errorCode":-400,"message":""},"formattedTime":"16:38:36","sessionId":"63546b68-030a-993a-02b4-3875-0ab15a356ce7","hasAccessRestriction":false,"realTime":-1,"hasSeasonalClosure":false,"hasCountryCross":false,"fuelUsed":36.05,"legs":[{"hasTollRoad":true,"hasBridge":false,"destNarrative":"Proceed to DELHI, DELHI.","distance":866.862,"hasTimedRestriction":false,"hasTunnel":false,"hasHighway":true,"index":0,"formattedTime":"16:38:36","origIndex":1,"hasAccessRestriction":false,"hasSeasonalClosure":false,"hasCountryCross":false,"roadGradeStrategy":[[]],"destIndex":51,"time":59916,"hasUnpaved":false,"origNarrative":"Go north on Ebrahim Rehmatullah Road.","maneuvers":[{"distance":0.083,"streets":[],"narrative":"Start out going east to
# ...

# %%
print(len(resp.text))
resp.text
# Out:
# 53126
# ...

# %%
texto=resp.text
json.loads(texto)
# Out:
# {'route': {'hasTollRoad': True,
#   'hasBridge': False,
#   'boundingBox': {'lr': {'lng': 77.227051, 'lat': 18.952568},
#    'ul': {'lng': 72.831856, 'lat': 28.657734}},
#   'distance': 866.862,
#   'hasTimedRestriction': False,
#   'hasTunnel': False,
#   'hasHighway': True,
#   'computedWaypoints': [],
#   'routeError': {'errorCode': -400, 'message': ''},
#   'formattedTime': '16:38:36',
#   'sessionId': '63546b68-030a-993a-02b4-3875-0ab15a356ce7',
#   'hasAccessRestriction': False,
#   'realTime': -1,
#   'hasSeasonalClosure': False,
#   'hasCountryCross': False,
#   'fuelUsed': 36.05,
#   'legs': [{'hasTollRoad': True,
#     'hasBridge': False,
#     'destNarrative': 'Proceed to DELHI, DELHI.',
#     'distance': 866.862,
#     'hasTimedRestriction': False,
#     'hasTunnel': False,
#     'hasHighway': True,
#     'index': 0,
#     'formattedTime': '16:38:36',
#     'origIndex': 1,
#     'hasAccessRestriction': False,
#     'hasSeasonalClosure': False,
# ...

# %%
jsondata=json.loads(texto)
resp2=pd.DataFrame.from_dict(jsondata)
resp2.head()
# Out:
#                                                                  route info
# hasTollRoad                                                       True  NaN
# hasBridge                                                        False  NaN
# boundingBox          {'lr': {'lng': 77.227051, 'lat': 18.952568}, '...  NaN
# distance                                                       866.862  NaN
# hasTimedRestriction                                              False  NaN

# %%
from pandas.io.json import json_normalize
json_normalize(jsondata['route'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#    hasTollRoad  hasBridge  distance  hasTimedRestriction  hasTunnel  \
# 0         True      False   866.862                False      False
#
#    hasHighway computedWaypoints formattedTime  \
# 0        True                []      16:38:36
#
#                                    sessionId  hasAccessRestriction  ...  \
# 0  63546b68-030a-993a-02b4-3875-0ab15a356ce7                 False  ...
#
#    options.walkingSpeed  options.urbanAvoidFactor  \
# 0                    -1                        -1
#
#    options.stateBoundaryDisplay  options.unit options.highwayEfficiency  \
# 0                          True             M                        22
#
#   options.maxLinkId  options.maneuverPenalty  options.avoidTripIds  \
# 0                 0                       -1                    []
#
# ...

# %%
json_normalize(jsondata['route']).shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
# (1, 58)
