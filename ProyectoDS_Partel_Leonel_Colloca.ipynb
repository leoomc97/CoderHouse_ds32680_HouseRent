# %% [markdown]
# #      **Trabajo Nº 3. Estructurando proyecto DS l **

# %% [markdown]
# Enlace a archivo guardado en drive.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Llamo a las librerias potenciales a utilizar.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Data science- Datasets/House rent dataset/House_Rent_Dataset.csv',index_col=0,sep=';')
df.head(5)
# Out:
#             BHK   Rent  Size            Floor    Area Type  \
# Posted On
# 18/05/2022    2  10000  1100  Ground out of 2   Super Area
# 13/05/2022    2  20000   800       1 out of 3   Super Area
# 16/05/2022    2  17000  1000       1 out of 3   Super Area
# 04/07/2022    2  10000   800       1 out of 2   Super Area
# 09/05/2022    2   7500   850       1 out of 2  Carpet Area
#
#                        Area Locality     City Furnishing Status  \
# Posted On
# 18/05/2022                    Bandel  Kolkata       Unfurnished
# 13/05/2022  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished
# 16/05/2022   Salt Lake City Sector 2  Kolkata    Semi-Furnished
# 04/07/2022               Dumdum Park  Kolkata       Unfurnished
# 09/05/2022             South Dum Dum  Kolkata       Unfurnished
#
#             Tenant Preferred  Bathroom Point of Contact
# Posted On
# 18/05/2022  Bachelors/Family         2    Contact Owner
# 13/05/2022  Bachelors/Family         1    Contact Owner
# ...

# %% [markdown]
# # ***Introducción***

# %% [markdown]
# Un poco teniendo el putno de partida la perspectiva el proyecto anterior a continuacion revisaremos visualizaciones de los diferentes factores que determinan el precio de una vivienda, el dataset se ve prometedor ya que tenemos datos de la zona/ciudad de la vivienda, cantidad de baños, tamaño, cantidad de pisos y hasta si la publicacion ha sido por dueño directo o por inmobiliaria, entendemos que todos ellos son factores determinantes para el precio pero en las siguientes visualizacions analizaremos y corrobaremos dichos datos para ver si efectivamente es asi y cuan determinante es cada factor a comparacion de los demas.-

# %% [markdown]
# # ***Serie de preguntas***

# %% [markdown]
# *   ¿La cantidad de oferta-demanda en una ciudad afecta el precio de las viviendas?
# *   ¿Que tan variante para el precio la Zona/Ciudad en la que se encuentra?
# *   ¿Que tanto afecta el precio la cantidad de baños que posee una vivienda?
# *   ¿Que tanto afecta al precio el tamaño de la vivienda?
# *   ¿El hecho del contacto de la vivienda sea dueño directo o inmobiliaria cambia el precio?

# %% [markdown]
# # ***Visualizaciones***

# %%
df['count'] = 1
DD = df.groupby(['City']).count()['count']
plt.figure(figsize=(12,6))
plt.pie(DD.values, labels=DD.index, startangle=90, autopct='%1.1f%%', shadow=True, radius=1.5)
plt.title("Porcentaje de ofertas por ciudad")
plt.minorticks_on()
plt.grid()

# %%
df.plot(kind='scatter', x='City', y='Rent')
plt.title("Precio de renta por Ciudad - India")
plt.legend()
plt.minorticks_on()
plt.grid()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ¿La cantidad de oferta-demanda en una ciudad afecta el precio de las viviendas?
# ¿Que tan variante para el precio la Zona/Ciudad en la que se encuentra?
#
# En los graficos podemos visualizar una gran cantidad de ofertas de viviendas en las ciudades como Mumbai,Chennai, Bangalore y Hyderabad. Las cuales rondan casi por la misma cantidad de ofertas de dichas viviendas.
# Sin embargo al visualizar el precio de la renta podemos visualizar que hay una dominancia en la parte alta de precio de renta en la ciudad de Mumbai, sacando de lado un inusual en la ciudad de bangalore, podemos concluir que la comparativa de oferta-demanda no es un factor razonable para este datraset debido a que efectivamente Mumbai es la zona con mas ofertas y ademas es la zona con la renta mas alta, consecuentemente nos lleva a indagar mas otros factores comparables para buscar razones del precio.
# El grafico de los precios tambien nos ayuda tener una nocion de los precios puntuales de cada zona la cual nos genera mas cuestiones de la causalidad de los precios, tales como si en la zona centrica (efectivamente Mumbai lo es) a comparacion de las demas ciudades del dataset ademas tambien la comparativa entre las demas ciudades, habria que investigar mas razones por la cual el precio se eleva mucho o no en cada uno de las ciudades en punual.-

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='City',y='Rent',hue='Bathroom',data=df)
plt.legend()
plt.minorticks_on()
plt.grid()

# %% [markdown]
# ¿Que tanto afecta el precio la cantidad de baños que posee una vivienda?
#
# En este grafico podemos visualizar la comparativa de las Ciudades con la cantidad de baños y su relacion con los precios, en el concluimos a travez de la visualizacion en como los precios de los mismos se disparan en los graficos de todas las ciudades cuando la vivienda cuenta con mas de baños a partir de 3 por vivienda, lo normal o los precios mas bajos podemos visualizar que son las viviendas con 2 baños o menos.
# Entonces afirmamos que los baños son un factor que hacen variar los precios de las viviendas y los mismos se diferencian demasiado a partir de los 2/3 baños por vivienda.-

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.scatterplot(x='Rent', y='Size',hue='City',data=df)
plt.legend()
plt.minorticks_on()
plt.grid()

# %% [markdown]
# ¿Que tanto afecta al precio el tamaño de la vivienda?
#
# En el siguiente grafico vemos la relacion entre el tamaño y el precio de la vivienda diferenciado por las ciudades, podemos visualizar los precios mas alejados corresponde a las ciudades mas caras que ademas tenemos los tamaños de casas mas espaciosas, vemos la preponderancia de Mumbai donde cuentan tendencia de viviendas mas espaciosas, por ende es razonable nuevamente que visualizemos cierta dominancia en tendencia alcista en cuanto a los precios de las viviendas, podemos afiermar que efectivamente el tamaño de la  vivienda es un factor determinante para el precio de la misma y podemos justificar la incognita  previa de porque Mumbai presenta dominancia, en efecto una de las causalidades es que cuenta con las viviendas con mayor tamaño en potecial demanda de la misma.-

# %%
df['count'] = 1
D = df.groupby(['Point of Contact']).count()['count']
plt.figure(figsize=(12,6))
plt.pie(D.values, labels=D.index, startangle=90, autopct='%1.1f%%', shadow=True, radius=1.5)
plt.title("Porcentaje de encargados de oferta de viviendas")
plt.minorticks_on()
plt.grid()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='City',y='Rent',hue='Point of Contact',data=df)
plt.legend()
plt.minorticks_on()
plt.grid()

# %% [markdown]
# ¿El hecho del contacto de la vivienda sea dueño directo o inmobiliaria cambia el precio?
#
# Efectivamente a travez de la visualizacion podemos visualizar que el hecho de que la vivienda sea ofrecida por agente como el precio se vuelve mas elevado, confirmamos que siempre es mas barato contactar con el dueño directo de la vivienda para ahorrarse dinero.
#
# En esta encontramos un inusual la cual podemos justificar la razon de siempre haber encontrado un inusual muy disparado en Hyderabad, esta se debe a que hay una constructora, la cual habria que investigar que se trata de una vivienda ofrecida por la constructora en si, con terminaciones en proceso o cualquier otra razon la cual se debe el porque de encontrarse siempre muy disparado cuando se realciona al precio.-
